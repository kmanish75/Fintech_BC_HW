# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_df = pd.read_csv("Resources/whale_returns.csv")
whale_returns_df.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
whale_returns_df.dtypes
# Out:
# Date                            object
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
whale_returns_df.set_index(pd.to_datetime(whale_returns_df['Date'], infer_datetime_format=True), inplace=True)
whale_returns_df.drop(columns=['Date'], inplace=True)
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_returns_df.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
whale_returns_df.shape
# Out:
# (1060, 4)

# %%
# Count nulls
whale_returns_df.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df= whale_returns_df.dropna()

# %%
whale_returns_df.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_returns_df.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
whale_returns_df.shape
# Out:
# (1059, 4)

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_df = pd.read_csv("Resources/algo_returns.csv")
algo_returns_df.head()
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
algo_returns_df.dtypes
# Out:
# Date       object
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
algo_returns_df.set_index(pd.to_datetime(algo_returns_df['Date'], infer_datetime_format=True), inplace=True)
algo_returns_df.drop(columns=['Date'], inplace=True)
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo_returns_df.shape
# Out:
# (1241, 2)

# %%
# Count nulls
algo_returns_df.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df= algo_returns_df.dropna()

# %%
algo_returns_df.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_returns_df.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
algo_returns_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
algo_returns_df.shape
# Out:
# (1235, 2)

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_df = pd.read_csv("Resources/sp500_history.csv")

# %%
sp500_history_df.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
sp500_history_df.set_index(pd.to_datetime(sp500_history_df['Date'], infer_datetime_format=True), inplace=True)
sp500_history_df.drop(columns=['Date'], inplace=True)
sp500_history_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
sp500_history_df.shape
# Out:
# (1649, 1)

# %%
# Check Data Types
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history_df['Close'] =sp500_history_df['Close'].str.replace('$', '')
# Out:
# <ipython-input-630-462a2457e93e>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_history_df['Close'] =sp500_history_df['Close'].str.replace('$', '')

# %%
sp500_history_df['Close']
# Out:
# Date
# 2019-04-23    2933.68
# 2019-04-22    2907.97
# 2019-04-18    2905.03
# 2019-04-17    2900.45
# 2019-04-16    2907.06
#                ...
# 2012-10-05    1460.93
# 2012-10-04    1461.40
# 2012-10-03    1450.99
# 2012-10-02    1445.75
# 2012-10-01    1444.49
# Name: Close, Length: 1649, dtype: object

# %%
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history_df['Close'] = sp500_history_df['Close'].astype('float')
sp500_history_df['Close'].dtype
# Out:
# dtype('float64')

# %%
# Calculate Daily Returns
sp500_returns_df = sp500_history_df.pct_change()
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
sp500_returns_df.shape
# Out:
# (1649, 1)

# %%
sp500_returns_df.isna().sum()
# Out:
# Close    1
# dtype: int64

# %%
# Drop nulls
sp500_returns_df = sp500_returns_df.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns_df = sp500_returns_df.rename(columns = {'Close': 'S&P500'}, inplace = False)
sp500_returns_df.head()
# Out:
#               S&P500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
sp500_returns_df.shape
# Out:
# (1648, 1)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_portfolios_df = pd.concat([whale_returns_df,algo_returns_df, sp500_returns_df], axis='columns', join='inner')
combined_portfolios_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_portfolios_df.plot(title="Portfolio Returns" , figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Portfolio Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_portfolios_df_cumulative_returns = (1 + combined_portfolios_df).cumprod()
combined_portfolios_df_cumulative_returns.head()

# Plot cumulative returns
combined_portfolios_df_cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_portfolios_df.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
portfolios_std_dev = combined_portfolios_df.std()
portfolios_std_dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P500                         0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std_dev = combined_portfolios_df['S&P500'].std()
sp500_std_dev
# Determine which portfolios are riskier than the S&P 500
portfolios_riskier_than_sp500 =[daily_std > sp500_std_dev]
portfolios_riskier_than_sp500
# Out:
# [SOROS FUND MANAGEMENT LLC      False
#  PAULSON & CO.INC.              False
#  TIGER GLOBAL MANAGEMENT LLC     True
#  BERKSHIRE HATHAWAY INC          True
#  Algo 1                         False
#  Algo 2                         False
#  S&P500                         False
#  dtype: bool]

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std_dev = portfolios_std_dev *np.sqrt(252)
annualized_std_dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P500                         0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_portfolios_df_rolling_std = combined_portfolios_df.rolling(window=21).std()
# Plot the rolling standard deviation
combined_portfolios_df_rolling_std.plot(title = "Portfolios Rolling Standard Deviation",figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Portfolios Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolios_correlation = combined_portfolios_df.corr()
# Display de correlation matrix
portfolios_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P500                                        0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
algo1_covariance = combined_portfolios_df['Algo 1'].rolling(window=60).cov(combined_portfolios_df['S&P500'])                                                        
algo1_covariance                                                        
# Calculate variance of S&P 500
sp_variance = combined_portfolios_df['S&P500'].rolling(window=60).var()                                                        
sp_variance
# Computing beta
algo1_beta = algo1_covariance / sp_variance
algo1_beta
# Plot beta trend
algo1_beta_plot = algo1_beta.plot(title = "Algo 1 Beta", figsize = (15,10))

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
rolling_window_portfolio_ewma = combined_portfolios_df.ewm(halflife = 21).std()
rolling_window_portfolio_ewma
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-15                   0.007755            0.006960
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
combined_portfolios_sharpe_ratios = (combined_portfolios_df.mean() * 252) / (combined_portfolios_df.std() * np.sqrt(252))
combined_portfolios_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P500                        -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_portfolios_sharpe_ratios.plot(kind="bar", title="Portfolios Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Portfolios Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo 1 Portfolio strategies outperform both the market and the whales portfolios as its sharpe ratio is higher than each of whales portfolio and market.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
#goog_df = pd.read_csv("Resources/goog_historical.csv", index_col='Trade DATE',infer_datetime_format=True)
goog_df = pd.read_csv("Resources/goog_historical.csv",infer_datetime_format=True)
goog_df.head()
# Out:
#   Symbol Trade DATE     NOCP
# 0   GOOG   5/9/2019  1162.38
# 1   GOOG   5/8/2019  1166.27
# 2   GOOG   5/7/2019  1174.10
# 3   GOOG   5/6/2019  1189.39
# 4   GOOG   5/3/2019  1185.40

# %%
# Reading data from 2nd stock
aapl_df = pd.read_csv("Resources/aapl_historical.csv",infer_datetime_format=True)
aapl_df.head()
# Out:
#   Symbol Trade DATE    NOCP
# 0   AAPL   5/9/2019  200.72
# 1   AAPL   5/8/2019  202.90
# 2   AAPL   5/7/2019  202.86
# 3   AAPL   5/6/2019  208.48
# 4   AAPL   5/3/2019  211.75

# %%
# Reading data from 3rd stock
cost_df = pd.read_csv("Resources/cost_historical.csv",infer_datetime_format=True)
cost_df.head()
# Out:
#   Symbol Trade DATE    NOCP
# 0   COST   5/9/2019  243.47
# 1   COST   5/8/2019  241.34
# 2   COST   5/7/2019  240.18
# 3   COST   5/6/2019  244.23
# 4   COST   5/3/2019  244.62

# %%
# goog_df.set_index(pd.to_datetime(goog_df['Trade DATE'], infer_datetime_format=True), inplace=True)
goog_df.columns = ['Symbol', 'Trade DATE', 'GOOG_NOCP']
# my_portfolio_df.head()
#goog_df.drop(columns=['Trade DATE'], inplace=True)
goog_df.head()
# Out:
#   Symbol Trade DATE  GOOG_NOCP
# 0   GOOG   5/9/2019    1162.38
# 1   GOOG   5/8/2019    1166.27
# 2   GOOG   5/7/2019    1174.10
# 3   GOOG   5/6/2019    1189.39
# 4   GOOG   5/3/2019    1185.40

# %%
#aapl_df.set_index(pd.to_datetime(aapl_df['Trade DATE'], infer_datetime_format=True), inplace=True)
aapl_df.columns = ['Symbol', 'Trade DATE', 'AAPL_NOCP']
#aapl_df.drop(columns=['Trade DATE'], inplace=True)
aapl_df.head()

# aapl_df.drop(columns=['Symbol'], inplace=True)
# aapl_df.head()
# Out:
#   Symbol Trade DATE  AAPL_NOCP
# 0   AAPL   5/9/2019     200.72
# 1   AAPL   5/8/2019     202.90
# 2   AAPL   5/7/2019     202.86
# 3   AAPL   5/6/2019     208.48
# 4   AAPL   5/3/2019     211.75

# %%
#cost_df.set_index(pd.to_datetime(cost_df['Trade DATE'], infer_datetime_format=True), inplace=True)
#cost_df.drop(columns=['Trade DATE'], inplace=True)
cost_df.columns = ['Symbol', 'Trade DATE', 'COST_NOCP']
cost_df.head()

# cost_df.drop(columns=['Symbol'], inplace=True)
# cost_df.head()
# Out:
#   Symbol Trade DATE  COST_NOCP
# 0   COST   5/9/2019     243.47
# 1   COST   5/8/2019     241.34
# 2   COST   5/7/2019     240.18
# 3   COST   5/6/2019     244.23
# 4   COST   5/3/2019     244.62

# %%
# Combine all stocks in a single DataFrame
# my_portfolio_df = pd.concat([goog_df, aapl_df['Symbol'],'NOCP'], cost_df['Symbol','NOCP']], axis="columns", join="inner")
my_portfolio_df = pd.concat([goog_df, aapl_df, cost_df], axis="columns", join="inner")
#my_portfolio_df.drop(columns=['Symbol'], inplace=True)
my_portfolio_df.head()
# Out:
#   Symbol Trade DATE  GOOG_NOCP Symbol Trade DATE  AAPL_NOCP Symbol Trade DATE  \
# 0   GOOG   5/9/2019    1162.38   AAPL   5/9/2019     200.72   COST   5/9/2019
# 1   GOOG   5/8/2019    1166.27   AAPL   5/8/2019     202.90   COST   5/8/2019
# 2   GOOG   5/7/2019    1174.10   AAPL   5/7/2019     202.86   COST   5/7/2019
# 3   GOOG   5/6/2019    1189.39   AAPL   5/6/2019     208.48   COST   5/6/2019
# 4   GOOG   5/3/2019    1185.40   AAPL   5/3/2019     211.75   COST   5/3/2019
#
#    COST_NOCP
# 0     243.47
# 1     241.34
# 2     240.18
# 3     244.23
# 4     244.62

# %%
# Reset Date index
my_portfolio_df.drop(columns=['Symbol'], inplace=True)
my_portfolio_df = my_portfolio_df.loc[:,~my_portfolio_df.columns.duplicated()]
# my_portfolio_df = my_portfolio_df.loc[:,~my_portfolio_df.columns.duplicated()]
my_portfolio_df.set_index(pd.to_datetime(my_portfolio_df['Trade DATE'], infer_datetime_format=True), inplace=True)
# my_portfolio_df.sort_index(inplace=True)
# my_portfolio_df.reset_index(drop=True)
my_portfolio_df.drop(columns=['Trade DATE'], inplace=True)
my_portfolio_df.head()
# Out:
#             GOOG_NOCP  AAPL_NOCP  COST_NOCP
# Trade DATE
# 2019-05-09    1162.38     200.72     243.47
# 2019-05-08    1166.27     202.90     241.34
# 2019-05-07    1174.10     202.86     240.18
# 2019-05-06    1189.39     208.48     244.23
# 2019-05-03    1185.40     211.75     244.62

# %%
# Reorganize portfolio data by having a column per symbol
my_portfolio_df.sort_index(inplace=True)
my_portfolio_df.columns = ['GOOG', 'AAPL', 'COST']
my_portfolio_df.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
# Calculate daily returns
my_portfolio_df.dropna()
my_portfolio_df
my_portfolio_returns = my_portfolio_df.pct_change()

# Drop NAs
my_portfolio_returns.dropna(inplace=True)

# Display sample data
my_portfolio_returns.sample(5)
# Out:
#                 GOOG      AAPL      COST
# Trade DATE
# 2019-03-08 -0.000857  0.002377  0.050879
# 2019-04-26  0.006910 -0.004774 -0.007248
# 2018-10-23  0.002298  0.009427 -0.001353
# 2018-12-27  0.004252 -0.006490  0.012334
# 2019-04-16  0.004938  0.000100 -0.004019

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_weighted_returns = my_portfolio_returns.dot(weights)
my_portfolio_weighted_returns = my_portfolio_weighted_returns.rename("Custom")
my_portfolio_weighted_returns.head()


# Display sample data
#my_portfolio_weighted_returns.sample()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# Name: Custom, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_portfolios_incl_myportfolio_df = pd.concat([whale_returns_df,algo_returns_df, sp500_returns_df, my_portfolio_weighted_returns], axis='columns', join='inner')
combined_portfolios_incl_myportfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2    S&P500    Custom
# 2018-05-14  0.001635  0.006889  0.000015
# 2018-05-15 -0.001139 -0.004044 -0.010064
# 2018-05-16  0.003341  0.000857  0.009403
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_portfolios_incl_myportfolio_df.dropna(inplace=True)
combined_portfolios_incl_myportfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2    S&P500    Custom
# 2018-05-14  0.001635  0.006889  0.000015
# 2018-05-15 -0.001139 -0.004044 -0.010064
# 2018-05-16  0.003341  0.000857  0.009403
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_portfolios_incl_myportfolio_df_daily_std = combined_portfolios_incl_myportfolio_df.std()
combined_portfolios_incl_myportfolio_df_annualized_std = combined_portfolios_incl_myportfolio_df_daily_std *np.sqrt(252)
combined_portfolios_incl_myportfolio_df_annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P500                         0.152469
# Custom                         0.211627
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_portfolios_incl_myportfolio_df_rolling_std = combined_portfolios_incl_myportfolio_df.rolling(window=21).std()

# Plot rolling standard deviation
combined_portfolios_incl_myportfolio_df_rolling_std.plot(title = "Portfolios (including my Portfolio) Rolling Standard Deviation",figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Portfolios (including my Portfolio) Rolling Standard Deviation'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

combined_portfolios_incl_myportfolio_df_rolling_correlation = combined_portfolios_incl_myportfolio_df.corr()
combined_portfolios_incl_myportfolio_df_rolling_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791802
# PAULSON & CO.INC.                             0.791802            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.477844            0.484869
# BERKSHIRE HATHAWAY INC                        0.816197            0.650390
# Algo 1                                        0.336909            0.360727
# Algo 2                                        0.862583            0.783865
# S&P500                                       -0.028256           -0.059862
# Custom                                        0.732548            0.643828
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.477844
# PAULSON & CO.INC.                               0.484869
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.324306
# ...

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
my_portfolio_covariance = combined_portfolios_incl_myportfolio_df['Custom'].rolling(window=60).cov(combined_portfolios_incl_myportfolio_df['S&P500'])                                                        
my_portfolio_covariance                                                        
# Calculate variance of S&P 500
sp500_variance = combined_portfolios_incl_myportfolio_df['S&P500'].rolling(window=60).var()                                                        
sp500_variance
# Computing beta
my_portfolio_beta = my_portfolio_covariance / sp500_variance
my_portfolio_beta
# Plot beta trend
my_portfolio_beta_plot = my_portfolio_beta.plot(title = "My Portfolio Beta", figsize = (15,10))

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
combined_portfolios_incl_myportfolio_sharpe_ratios = (combined_portfolios_incl_myportfolio_df.mean() * 252) / (combined_portfolios_incl_myportfolio_df.std() * np.sqrt(252))
combined_portfolios_incl_myportfolio_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P500                        -0.427676
# Custom                         0.876152
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_portfolios_incl_myportfolio_sharpe_ratios.plot(kind="bar", title="Portfolios including Cusustom Portfolio's Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':"Portfolios including Cusustom Portfolio's Sharpe Ratios"}>

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio is performing better than all other portfolios except Algo1 portfolio.
